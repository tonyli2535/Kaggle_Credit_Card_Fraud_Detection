# %%
# !pip install kagglehub --upgrade --quiet
import kagglehub
import pandas as pd
from sklearn.model_selection import train_test_split
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers
from sklearn.preprocessing import RobustScaler
from sklearn.utils.class_weight import compute_class_weight
import numpy as np
import pandas as pd
path = kagglehub.dataset_download("mlg-ulb/creditcardfraud")
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 69.3/69.3 kB 3.2 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 160.4/160.4 kB 3.3 MB/s eta 0:00:00
# Using Colab cache for faster access to the 'creditcardfraud' dataset.

# %%
# !pip install ydata-profiling
from ydata_profiling import ProfileReport
# Out:
# Collecting ydata-profiling
#   Downloading ydata_profiling-4.18.1-py2.py3-none-any.whl.metadata (22 kB)
# Requirement already satisfied: scipy<1.17,>=1.8 in /usr/local/lib/python3.12/dist-packages (from ydata-profiling) (1.16.3)
# Requirement already satisfied: pandas!=1.4.0,<3.0,>1.5 in /usr/local/lib/python3.12/dist-packages (from ydata-profiling) (2.2.2)
# Requirement already satisfied: matplotlib<=3.10,>=3.5 in /usr/local/lib/python3.12/dist-packages (from ydata-profiling) (3.10.0)
# Requirement already satisfied: pydantic<3,>=2 in /usr/local/lib/python3.12/dist-packages (from ydata-profiling) (2.12.3)
# Requirement already satisfied: PyYAML<6.1,>=6.0.3 in /usr/local/lib/python3.12/dist-packages (from ydata-profiling) (6.0.3)
# Requirement already satisfied: jinja2<3.2,>=3.1.6 in /usr/local/lib/python3.12/dist-packages (from ydata-profiling) (3.1.6)
# Collecting visions<0.8.2,>=0.7.5 (from visions[type_image_path]<0.8.2,>=0.7.5->ydata-profiling)
#   Downloading visions-0.8.1-py3-none-any.whl.metadata (11 kB)
# Requirement already satisfied: numpy<2.4,>=1.22 in /usr/local/lib/python3.12/dist-packages (from ydata-profiling) (2.0.2)
# Collecting minify-html>=0.15.0 (from ydata-profiling)
#   Downloading minify_html-0.18.1-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (18 kB)
# Collecting filetype>=1.0.0 (from ydata-profiling)
#   Downloading filetype-1.2.0-py2.py3-none-any.whl.metadata (6.5 kB)
# Collecting phik<0.13,>=0.12.5 (from ydata-profiling)
#   Downloading phik-0.12.5-cp312-cp312-manylinux_2_24_x86_64.manylinux_2_28_x86_64.whl.metadata (5.6 kB)
# Requirement already satisfied: requests<3,>=2.32.0 in /usr/local/lib/python3.12/dist-packages (from ydata-profiling) (2.32.4)
# Requirement already satisfied: tqdm<5,>=4.66.3 in /usr/local/lib/python3.12/dist-packages (from ydata-profiling) (4.67.1)
# Requirement already satisfied: seaborn<0.14,>=0.10.1 in /usr/local/lib/python3.12/dist-packages (from ydata-profiling) (0.13.2)
# Collecting multimethod<2,>=1.4 (from ydata-profiling)
#   Downloading multimethod-1.12-py3-none-any.whl.metadata (9.6 kB)
# Requirement already satisfied: statsmodels<1,>=0.13.2 in /usr/local/lib/python3.12/dist-packages (from ydata-profiling) (0.14.6)
# Requirement already satisfied: typeguard<5,>=4 in /usr/local/lib/python3.12/dist-packages (from ydata-profiling) (4.4.4)
# Collecting imagehash==4.3.2 (from ydata-profiling)
#   Downloading ImageHash-4.3.2-py2.py3-none-any.whl.metadata (8.4 kB)
# Requirement already satisfied: wordcloud>=1.9.4 in /usr/local/lib/python3.12/dist-packages (from ydata-profiling) (1.9.6)
# Collecting dacite<2,>=1.9 (from ydata-profiling)
#   Downloading dacite-1.9.2-py3-none-any.whl.metadata (17 kB)
# Requirement already satisfied: numba<0.63,>=0.60 in /usr/local/lib/python3.12/dist-packages (from ydata-profiling) (0.60.0)
# Requirement already satisfied: PyWavelets in /usr/local/lib/python3.12/dist-packages (from imagehash==4.3.2->ydata-profiling) (1.9.0)
# Requirement already satisfied: pillow in /usr/local/lib/python3.12/dist-packages (from imagehash==4.3.2->ydata-profiling) (11.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.12/dist-packages (from jinja2<3.2,>=3.1.6->ydata-profiling) (3.0.3)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib<=3.10,>=3.5->ydata-profiling) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.12/dist-packages (from matplotlib<=3.10,>=3.5->ydata-profiling) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.12/dist-packages (from matplotlib<=3.10,>=3.5->ydata-profiling) (4.61.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib<=3.10,>=3.5->ydata-profiling) (1.4.9)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.12/dist-packages (from matplotlib<=3.10,>=3.5->ydata-profiling) (25.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib<=3.10,>=3.5->ydata-profiling) (3.3.2)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.12/dist-packages (from matplotlib<=3.10,>=3.5->ydata-profiling) (2.9.0.post0)
# Requirement already satisfied: llvmlite<0.44,>=0.43.0dev0 in /usr/local/lib/python3.12/dist-packages (from numba<0.63,>=0.60->ydata-profiling) (0.43.0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.12/dist-packages (from pandas!=1.4.0,<3.0,>1.5->ydata-profiling) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.12/dist-packages (from pandas!=1.4.0,<3.0,>1.5->ydata-profiling) (2025.3)
# Requirement already satisfied: joblib>=0.14.1 in /usr/local/lib/python3.12/dist-packages (from phik<0.13,>=0.12.5->ydata-profiling) (1.5.3)
# Requirement already satisfied: annotated-types>=0.6.0 in /usr/local/lib/python3.12/dist-packages (from pydantic<3,>=2->ydata-profiling) (0.7.0)
# Requirement already satisfied: pydantic-core==2.41.4 in /usr/local/lib/python3.12/dist-packages (from pydantic<3,>=2->ydata-profiling) (2.41.4)
# Requirement already satisfied: typing-extensions>=4.14.1 in /usr/local/lib/python3.12/dist-packages (from pydantic<3,>=2->ydata-profiling) (4.15.0)
# Requirement already satisfied: typing-inspection>=0.4.2 in /usr/local/lib/python3.12/dist-packages (from pydantic<3,>=2->ydata-profiling) (0.4.2)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests<3,>=2.32.0->ydata-profiling) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests<3,>=2.32.0->ydata-profiling) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests<3,>=2.32.0->ydata-profiling) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.12/dist-packages (from requests<3,>=2.32.0->ydata-profiling) (2026.1.4)
# Requirement already satisfied: patsy>=0.5.6 in /usr/local/lib/python3.12/dist-packages (from statsmodels<1,>=0.13.2->ydata-profiling) (1.0.2)
# Requirement already satisfied: attrs>=19.3.0 in /usr/local/lib/python3.12/dist-packages (from visions<0.8.2,>=0.7.5->visions[type_image_path]<0.8.2,>=0.7.5->ydata-profiling) (25.4.0)
# Requirement already satisfied: networkx>=2.4 in /usr/local/lib/python3.12/dist-packages (from visions<0.8.2,>=0.7.5->visions[type_image_path]<0.8.2,>=0.7.5->ydata-profiling) (3.6.1)
# Collecting puremagic (from visions<0.8.2,>=0.7.5->visions[type_image_path]<0.8.2,>=0.7.5->ydata-profiling)
#   Downloading puremagic-1.30-py3-none-any.whl.metadata (5.8 kB)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.12/dist-packages (from python-dateutil>=2.7->matplotlib<=3.10,>=3.5->ydata-profiling) (1.17.0)
# Downloading ydata_profiling-4.18.1-py2.py3-none-any.whl (400 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 400.4/400.4 kB 4.8 MB/s eta 0:00:00
# Downloading ImageHash-4.3.2-py2.py3-none-any.whl (296 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 296.7/296.7 kB 23.6 MB/s eta 0:00:00
# Downloading dacite-1.9.2-py3-none-any.whl (16 kB)
# Downloading filetype-1.2.0-py2.py3-none-any.whl (19 kB)
# Downloading minify_html-0.18.1-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (3.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.1/3.1 MB 40.4 MB/s eta 0:00:00
# Downloading multimethod-1.12-py3-none-any.whl (10 kB)
# Downloading phik-0.12.5-cp312-cp312-manylinux_2_24_x86_64.manylinux_2_28_x86_64.whl (679 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 679.7/679.7 kB 51.6 MB/s eta 0:00:00
# Downloading visions-0.8.1-py3-none-any.whl (105 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 105.4/105.4 kB 7.5 MB/s eta 0:00:00
# Downloading puremagic-1.30-py3-none-any.whl (43 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 43.3/43.3 kB 3.9 MB/s eta 0:00:00
# Installing collected packages: puremagic, minify-html, filetype, multimethod, dacite, imagehash, visions, phik, ydata-profiling
# Successfully installed dacite-1.9.2 filetype-1.2.0 imagehash-4.3.2 minify-html-0.18.1 multimethod-1.12 phik-0.12.5 puremagic-1.30 visions-0.8.1 ydata-profiling-4.18.1

# %%
path = f'{path}/creditcard.csv'
df = pd.read_csv(path)

# %%
profile = ProfileReport(df, title="Data Profile Report", explorative=True)
profile.to_file("output_report.html")
# Out:
# Summarize dataset:   0%|          | 0/5 [00:00<?, ?it/s]
#   0%|          | 0/31 [00:00<?, ?it/s]
#   3%|▎         | 1/31 [00:00<00:27,  1.07it/s]
#   6%|▋         | 2/31 [00:01<00:17,  1.62it/s]
#  10%|▉         | 3/31 [00:03<00:31,  1.11s/it]
#  13%|█▎        | 4/31 [00:03<00:19,  1.36it/s]
#  16%|█▌        | 5/31 [00:06<00:40,  1.57s/it]
#  23%|██▎       | 7/31 [00:08<00:29,  1.24s/it]
#  29%|██▉       | 9/31 [00:08<00:19,  1.15it/s]
#  35%|███▌      | 11/31 [00:09<00:13,  1.50it/s]
#  42%|████▏     | 13/31 [00:10<00:09,  1.84it/s]
#  45%|████▌     | 14/31 [00:10<00:07,  2.14it/s]
#  48%|████▊     | 15/31 [00:10<00:07,  2.07it/s]
#  52%|█████▏    | 16/31 [00:10<00:06,  2.42it/s]
#  55%|█████▍    | 17/31 [00:11<00:06,  2.20it/s]
#  61%|██████▏   | 19/31 [00:12<00:04,  2.42it/s]
#  68%|██████▊   | 21/31 [00:13<00:04,  2.48it/s]
#  74%|███████▍  | 23/31 [00:13<00:03,  2.65it/s]
#  81%|████████  | 25/31 [00:14<00:02,  2.73it/s]
#  87%|████████▋ | 27/31 [00:15<00:01,  2.82it/s]
#  90%|█████████ | 28/31 [00:15<00:00,  3.16it/s]
# 100%|██████████| 31/31 [00:15<00:00,  1.95it/s]
# Generate report structure:   0%|          | 0/1 [00:00<?, ?it/s]
# Render HTML:   0%|          | 0/1 [00:00<?, ?it/s]
# Export report to file:   0%|          | 0/1 [00:00<?, ?it/s]

# %%
X = df.drop('Class', axis=1)
y = df['Class']
train_x, temp_x, train_y, temp_y = train_test_split(
    X,y,
    test_size = 0.3,
    random_state = 42,
    stratify = y

)

val_x, test_x, val_y, test_y = train_test_split(
    temp_x, temp_y,
    test_size=0.5,
    random_state=42,
    stratify = temp_y
)

scaler = RobustScaler()
train_x[['Amount', 'Time']] = scaler.fit_transform(train_x[['Amount', 'Time']])
val_x[['Amount', 'Time']]   = scaler.transform(val_x[['Amount', 'Time']])
test_x[['Amount', 'Time']]  = scaler.transform(test_x[['Amount', 'Time']])

train_x_np = train_x.to_numpy().astype(np.float32)
train_y_np = train_y.to_numpy().astype(np.float32)
val_x_np = val_x.to_numpy().astype(np.float32)
val_y_np = val_y.to_numpy().astype(np.float32)
test_x_np = test_x.to_numpy().astype(np.float32)
test_y_np = test_y.to_numpy().astype(np.float32)
class_weight = compute_class_weight(
    class_weight='balanced',
    classes=np.unique(train_y),
    y=train_y
)
class_weight_dict = {0:class_weight[0],1:class_weight[1]}

# %%
model = keras.Sequential([
    layers.Input(shape=(train_x_np.shape[1],)),
    layers.Dense(256,activation='relu'),
    layers.BatchNormalization(),
    layers.Dropout(0.2),
    layers.Dense(128,activation='relu'),
    layers.BatchNormalization(),
    layers.Dropout(0.2),
    layers.Dense(64,activation='relu'),
    layers.BatchNormalization(),
    layers.Dropout(0.2),
    layers.Dense(1,activation='sigmoid')
])

model.compile(
    optimizer = keras.optimizers.Adam(learning_rate = 0.001),
    loss = keras.losses.BinaryCrossentropy,
    metrics = [
        keras.metrics.AUC(name='pr_auc', curve='PR'),
        keras.metrics.AUC(name='roc_auc', curve='ROC'),
        keras.metrics.BinaryAccuracy(),
        keras.metrics.Precision(),
        keras.metrics.Recall()
    ]
)

early_stop = keras.callbacks.EarlyStopping(monitor='val_pr_auc',mode='max',patience=18, restore_best_weights=True, verbose=1)
reduce_lr = keras.callbacks.ReduceLROnPlateau(monitor='val_pr_auc',mode='max',patience=12)

# %%
history = model.fit(
    train_x_np, train_y_np,
    validation_data=(val_x_np, val_y_np),
    epochs=60,
    batch_size=2048,
    class_weight=class_weight_dict,
    callbacks=[early_stop, reduce_lr],
    verbose=1
)
# Out:
# Epoch 1/60
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 9s 48ms/step - binary_accuracy: 0.5888 - loss: 0.7057 - pr_auc: 0.1124 - precision_5: 0.0039 - recall_5: 0.8626 - roc_auc: 0.8642 - val_binary_accuracy: 0.9772 - val_loss: 0.3482 - val_pr_auc: 0.5951 - val_precision_5: 0.0615 - val_recall_5: 0.8514 - val_roc_auc: 0.9500 - learning_rate: 0.0010
# Epoch 2/60
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 4s 41ms/step - binary_accuracy: 0.8634 - loss: 0.2660 - pr_auc: 0.2530 - precision_5: 0.0118 - recall_5: 0.9449 - roc_auc: 0.9764 - val_binary_accuracy: 0.9863 - val_loss: 0.1901 - val_pr_auc: 0.5574 - val_precision_5: 0.0976 - val_recall_5: 0.8378 - val_roc_auc: 0.9604 - learning_rate: 0.0010
# Epoch 3/60
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 5s 52ms/step - binary_accuracy: 0.9417 - loss: 0.1869 - pr_auc: 0.3335 - precision_5: 0.0291 - recall_5: 0.9454 - roc_auc: 0.9845 - val_binary_accuracy: 0.9911 - val_loss: 0.1255 - val_pr_auc: 0.5418 - val_precision_5: 0.1419 - val_recall_5: 0.8243 - val_roc_auc: 0.9613 - learning_rate: 0.0010
# Epoch 4/60
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 4s 40ms/step - binary_accuracy: 0.9618 - loss: 0.1652 - pr_auc: 0.3904 - precision_5: 0.0424 - recall_5: 0.9206 - roc_auc: 0.9860 - val_binary_accuracy: 0.9804 - val_loss: 0.1231 - val_pr_auc: 0.5355 - val_precision_5: 0.0700 - val_recall_5: 0.8378 - val_roc_auc: 0.9668 - learning_rate: 0.0010
# Epoch 5/60
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 6s 61ms/step - binary_accuracy: 0.9654 - loss: 0.1537 - pr_auc: 0.3836 - precision_5: 0.0451 - recall_5: 0.9460 - roc_auc: 0.9840 - val_binary_accuracy: 0.9831 - val_loss: 0.0998 - val_pr_auc: 0.4292 - val_precision_5: 0.0805 - val_recall_5: 0.8378 - val_roc_auc: 0.9667 - learning_rate: 0.0010
# Epoch 6/60
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 4s 43ms/step - binary_accuracy: 0.9744 - loss: 0.1174 - pr_auc: 0.4406 - precision_5: 0.0544 - recall_5: 0.9306 - roc_auc: 0.9919 - val_binary_accuracy: 0.9835 - val_loss: 0.0956 - val_pr_auc: 0.4795 - val_precision_5: 0.0844 - val_recall_5: 0.8649 - val_roc_auc: 0.9567 - learning_rate: 0.0010
# Epoch 7/60
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 4s 38ms/step - binary_accuracy: 0.9752 - loss: 0.0924 - pr_auc: 0.4995 - precision_5: 0.0653 - recall_5: 0.9682 - roc_auc: 0.9956 - val_binary_accuracy: 0.9771 - val_loss: 0.1084 - val_pr_auc: 0.4194 - val_precision_5: 0.0646 - val_recall_5: 0.9054 - val_roc_auc: 0.9723 - learning_rate: 0.0010
# Epoch 8/60
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 5s 54ms/step - binary_accuracy: 0.9707 - loss: 0.0924 - pr_auc: 0.4098 - precision_5: 0.0520 - recall_5: 0.9653 - roc_auc: 0.9956 - val_binary_accuracy: 0.9834 - val_loss: 0.0842 - val_pr_auc: 0.3809 - val_precision_5: 0.0860 - val_recall_5: 0.8919 - val_roc_auc: 0.9606 - learning_rate: 0.0010
# Epoch 9/60
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 4s 38ms/step - binary_accuracy: 0.9728 - loss: 0.0897 - pr_auc: 0.3744 - precision_5: 0.0546 - recall_5: 0.9525 - roc_auc: 0.9960 - val_binary_accuracy: 0.9869 - val_loss: 0.0688 - val_pr_auc: 0.5968 - val_precision_5: 0.1055 - val_recall_5: 0.8784 - val_roc_auc: 0.9641 - learning_rate: 0.0010
# Epoch 10/60
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 4s 39ms/step - binary_accuracy: 0.9743 - loss: 0.0771 - pr_auc: 0.4426 - precision_5: 0.0589 - recall_5: 0.9625 - roc_auc: 0.9972 - val_binary_accuracy: 0.9856 - val_loss: 0.0661 - val_pr_auc: 0.5539 - val_precision_5: 0.0970 - val_recall_5: 0.8784 - val_roc_auc: 0.9634 - learning_rate: 0.0010
# Epoch 11/60
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 6s 59ms/step - binary_accuracy: 0.9783 - loss: 0.0564 - pr_auc: 0.5406 - precision_5: 0.0742 - recall_5: 0.9901 - roc_auc: 0.9986 - val_binary_accuracy: 0.9904 - val_loss: 0.0538 - val_pr_auc: 0.5901 - val_precision_5: 0.1385 - val_recall_5: 0.8649 - val_roc_auc: 0.9668 - learning_rate: 0.0010
# Epoch 12/60
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 5s 48ms/step - binary_accuracy: 0.9807 - loss: 0.0582 - pr_auc: 0.6305 - precision_5: 0.0788 - recall_5: 0.9867 - roc_auc: 0.9983 - val_binary_accuracy: 0.9871 - val_loss: 0.0574 - val_pr_auc: 0.6017 - val_precision_5: 0.1054 - val_recall_5: 0.8649 - val_roc_auc: 0.9614 - learning_rate: 0.0010
# Epoch 13/60
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 4s 40ms/step - binary_accuracy: 0.9795 - loss: 0.0841 - pr_auc: 0.5391 - precision_5: 0.0771 - recall_5: 0.9841 - roc_auc: 0.9938 - val_binary_accuracy: 0.9829 - val_loss: 0.0695 - val_pr_auc: 0.4462 - val_precision_5: 0.0814 - val_recall_5: 0.8649 - val_roc_auc: 0.9652 - learning_rate: 0.0010
# Epoch 14/60
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 5s 53ms/step - binary_accuracy: 0.9784 - loss: 0.0613 - pr_auc: 0.5062 - precision_5: 0.0739 - recall_5: 0.9821 - roc_auc: 0.9973 - val_binary_accuracy: 0.9905 - val_loss: 0.0426 - val_pr_auc: 0.6023 - val_precision_5: 0.1363 - val_recall_5: 0.8378 - val_roc_auc: 0.9583 - learning_rate: 0.0010
# Epoch 15/60
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 4s 41ms/step - binary_accuracy: 0.9819 - loss: 0.0584 - pr_auc: 0.5690 - precision_5: 0.0842 - recall_5: 0.9710 - roc_auc: 0.9982 - val_binary_accuracy: 0.9871 - val_loss: 0.0507 - val_pr_auc: 0.5602 - val_precision_5: 0.1048 - val_recall_5: 0.8514 - val_roc_auc: 0.9636 - learning_rate: 0.0010
# Epoch 16/60
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 6s 52ms/step - binary_accuracy: 0.9714 - loss: 0.0876 - pr_auc: 0.2435 - precision_5: 0.0576 - recall_5: 0.9823 - roc_auc: 0.9957 - val_binary_accuracy: 0.9931 - val_loss: 0.0384 - val_pr_auc: 0.5895 - val_precision_5: 0.1834 - val_recall_5: 0.8649 - val_roc_auc: 0.9533 - learning_rate: 0.0010
# Epoch 17/60
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 4s 42ms/step - binary_accuracy: 0.9799 - loss: 0.0640 - pr_auc: 0.4340 - precision_5: 0.0727 - recall_5: 0.9655 - roc_auc: 0.9975 - val_binary_accuracy: 0.9872 - val_loss: 0.0522 - val_pr_auc: 0.5498 - val_precision_5: 0.1063 - val_recall_5: 0.8649 - val_roc_auc: 0.9654 - learning_rate: 0.0010
# Epoch 18/60
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 4s 40ms/step - binary_accuracy: 0.9765 - loss: 0.0714 - pr_auc: 0.4242 - precision_5: 0.0677 - recall_5: 0.9812 - roc_auc: 0.9960 - val_binary_accuracy: 0.9882 - val_loss: 0.0496 - val_pr_auc: 0.5157 - val_precision_5: 0.1147 - val_recall_5: 0.8649 - val_roc_auc: 0.9608 - learning_rate: 0.0010
# Epoch 19/60
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 5s 52ms/step - binary_accuracy: 0.9793 - loss: 0.0688 - pr_auc: 0.5055 - precision_5: 0.0815 - recall_5: 0.9714 - roc_auc: 0.9974 - val_binary_accuracy: 0.9892 - val_loss: 0.0434 - val_pr_auc: 0.6035 - val_precision_5: 0.1228 - val_recall_5: 0.8514 - val_roc_auc: 0.9460 - learning_rate: 0.0010
# Epoch 20/60
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 4s 40ms/step - binary_accuracy: 0.9853 - loss: 0.0511 - pr_auc: 0.5923 - precision_5: 0.0990 - recall_5: 0.9770 - roc_auc: 0.9869 - val_binary_accuracy: 0.9934 - val_loss: 0.0351 - val_pr_auc: 0.5994 - val_precision_5: 0.1856 - val_recall_5: 0.8378 - val_roc_auc: 0.9489 - learning_rate: 0.0010
# Epoch 21/60
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 4s 39ms/step - binary_accuracy: 0.9856 - loss: 0.0475 - pr_auc: 0.5604 - precision_5: 0.1101 - recall_5: 0.9898 - roc_auc: 0.9981 - val_binary_accuracy: 0.9931 - val_loss: 0.0336 - val_pr_auc: 0.5789 - val_precision_5: 0.1816 - val_recall_5: 0.8514 - val_roc_auc: 0.9434 - learning_rate: 0.0010
# Epoch 22/60
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 5s 50ms/step - binary_accuracy: 0.9859 - loss: 0.0435 - pr_auc: 0.6264 - precision_5: 0.1111 - recall_5: 0.9869 - roc_auc: 0.9989 - val_binary_accuracy: 0.9893 - val_loss: 0.0420 - val_pr_auc: 0.5453 - val_precision_5: 0.1228 - val_recall_5: 0.8378 - val_roc_auc: 0.9547 - learning_rate: 0.0010
# Epoch 23/60
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 4s 40ms/step - binary_accuracy: 0.9861 - loss: 0.0373 - pr_auc: 0.6488 - precision_5: 0.1119 - recall_5: 0.9954 - roc_auc: 0.9991 - val_binary_accuracy: 0.9907 - val_loss: 0.0377 - val_pr_auc: 0.5347 - val_precision_5: 0.1406 - val_recall_5: 0.8514 - val_roc_auc: 0.9450 - learning_rate: 0.0010
# Epoch 24/60
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 4s 40ms/step - binary_accuracy: 0.9852 - loss: 0.0440 - pr_auc: 0.5200 - precision_5: 0.1010 - recall_5: 0.9795 - roc_auc: 0.9986 - val_binary_accuracy: 0.9917 - val_loss: 0.0331 - val_pr_auc: 0.5787 - val_precision_5: 0.1527 - val_recall_5: 0.8378 - val_roc_auc: 0.9524 - learning_rate: 0.0010
# Epoch 25/60
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 5s 53ms/step - binary_accuracy: 0.9849 - loss: 0.0452 - pr_auc: 0.5151 - precision_5: 0.1010 - recall_5: 0.9771 - roc_auc: 0.9986 - val_binary_accuracy: 0.9911 - val_loss: 0.0346 - val_pr_auc: 0.5334 - val_precision_5: 0.1475 - val_recall_5: 0.8649 - val_roc_auc: 0.9582 - learning_rate: 0.0010
# Epoch 26/60
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 4s 42ms/step - binary_accuracy: 0.9885 - loss: 0.0292 - pr_auc: 0.6172 - precision_5: 0.1229 - recall_5: 0.9949 - roc_auc: 0.9993 - val_binary_accuracy: 0.9927 - val_loss: 0.0362 - val_pr_auc: 0.4618 - val_precision_5: 0.1744 - val_recall_5: 0.8649 - val_roc_auc: 0.9491 - learning_rate: 0.0010
# Epoch 27/60
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 5s 40ms/step - binary_accuracy: 0.9892 - loss: 0.0299 - pr_auc: 0.5785 - precision_5: 0.1482 - recall_5: 0.9961 - roc_auc: 0.9991 - val_binary_accuracy: 0.9916 - val_loss: 0.0347 - val_pr_auc: 0.5068 - val_precision_5: 0.1529 - val_recall_5: 0.8514 - val_roc_auc: 0.9498 - learning_rate: 0.0010
# Epoch 28/60
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 5s 55ms/step - binary_accuracy: 0.9882 - loss: 0.0445 - pr_auc: 0.5246 - precision_5: 0.1225 - recall_5: 0.9804 - roc_auc: 0.9985 - val_binary_accuracy: 0.9886 - val_loss: 0.0418 - val_pr_auc: 0.5103 - val_precision_5: 0.1181 - val_recall_5: 0.8649 - val_roc_auc: 0.9464 - learning_rate: 0.0010
# Epoch 29/60
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 6s 60ms/step - binary_accuracy: 0.9887 - loss: 0.0308 - pr_auc: 0.6189 - precision_5: 0.1398 - recall_5: 0.9905 - roc_auc: 0.9992 - val_binary_accuracy: 0.9898 - val_loss: 0.0466 - val_pr_auc: 0.4340 - val_precision_5: 0.1273 - val_recall_5: 0.8378 - val_roc_auc: 0.9292 - learning_rate: 0.0010
# Epoch 30/60
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 8s 41ms/step - binary_accuracy: 0.9867 - loss: 0.0396 - pr_auc: 0.4667 - precision_5: 0.1101 - recall_5: 0.9916 - roc_auc: 0.9986 - val_binary_accuracy: 0.9864 - val_loss: 0.0521 - val_pr_auc: 0.4298 - val_precision_5: 0.1005 - val_recall_5: 0.8649 - val_roc_auc: 0.9411 - learning_rate: 0.0010
# Epoch 31/60
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 4s 40ms/step - binary_accuracy: 0.9859 - loss: 0.0333 - pr_auc: 0.5424 - precision_5: 0.1143 - recall_5: 0.9998 - roc_auc: 0.9989 - val_binary_accuracy: 0.9928 - val_loss: 0.0284 - val_pr_auc: 0.6283 - val_precision_5: 0.1755 - val_recall_5: 0.8514 - val_roc_auc: 0.9437 - learning_rate: 0.0010
# Epoch 32/60
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 6s 53ms/step - binary_accuracy: 0.9875 - loss: 0.0315 - pr_auc: 0.6310 - precision_5: 0.1197 - recall_5: 0.9939 - roc_auc: 0.9992 - val_binary_accuracy: 0.9903 - val_loss: 0.0381 - val_pr_auc: 0.4965 - val_precision_5: 0.1349 - val_recall_5: 0.8514 - val_roc_auc: 0.9502 - learning_rate: 0.0010
# Epoch 33/60
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 4s 40ms/step - binary_accuracy: 0.9879 - loss: 0.0298 - pr_auc: 0.5583 - precision_5: 0.1269 - recall_5: 0.9960 - roc_auc: 0.9991 - val_binary_accuracy: 0.9922 - val_loss: 0.0316 - val_pr_auc: 0.5340 - val_precision_5: 0.1649 - val_recall_5: 0.8649 - val_roc_auc: 0.9446 - learning_rate: 0.0010
# Epoch 34/60
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 4s 41ms/step - binary_accuracy: 0.9890 - loss: 0.0365 - pr_auc: 0.5297 - precision_5: 0.1350 - recall_5: 0.9916 - roc_auc: 0.9988 - val_binary_accuracy: 0.9902 - val_loss: 0.0314 - val_pr_auc: 0.6257 - val_precision_5: 0.1325 - val_recall_5: 0.8378 - val_roc_auc: 0.9370 - learning_rate: 0.0010
# Epoch 35/60
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 7s 58ms/step - binary_accuracy: 0.9894 - loss: 0.0257 - pr_auc: 0.6209 - precision_5: 0.1463 - recall_5: 0.9969 - roc_auc: 0.9993 - val_binary_accuracy: 0.9949 - val_loss: 0.0242 - val_pr_auc: 0.5868 - val_precision_5: 0.2313 - val_recall_5: 0.8378 - val_roc_auc: 0.9389 - learning_rate: 0.0010
# Epoch 36/60
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 4s 41ms/step - binary_accuracy: 0.9924 - loss: 0.0196 - pr_auc: 0.6972 - precision_5: 0.1937 - recall_5: 0.9999 - roc_auc: 0.9995 - val_binary_accuracy: 0.9955 - val_loss: 0.0222 - val_pr_auc: 0.5730 - val_precision_5: 0.2551 - val_recall_5: 0.8378 - val_roc_auc: 0.9329 - learning_rate: 0.0010
# Epoch 37/60
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 6s 52ms/step - binary_accuracy: 0.9878 - loss: 0.0298 - pr_auc: 0.5062 - precision_5: 0.1254 - recall_5: 0.9938 - roc_auc: 0.9989 - val_binary_accuracy: 0.9937 - val_loss: 0.0257 - val_pr_auc: 0.6372 - val_precision_5: 0.1981 - val_recall_5: 0.8649 - val_roc_auc: 0.9381 - learning_rate: 0.0010
# Epoch 38/60
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 4s 41ms/step - binary_accuracy: 0.9908 - loss: 0.0291 - pr_auc: 0.6726 - precision_5: 0.1567 - recall_5: 0.9905 - roc_auc: 0.9993 - val_binary_accuracy: 0.9957 - val_loss: 0.0251 - val_pr_auc: 0.5944 - val_precision_5: 0.2672 - val_recall_5: 0.8378 - val_roc_auc: 0.9401 - learning_rate: 0.0010
# Epoch 39/60
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 4s 40ms/step - binary_accuracy: 0.9937 - loss: 0.0192 - pr_auc: 0.7209 - precision_5: 0.2168 - recall_5: 0.9984 - roc_auc: 0.9996 - val_binary_accuracy: 0.9943 - val_loss: 0.0259 - val_pr_auc: 0.5941 - val_precision_5: 0.2102 - val_recall_5: 0.8378 - val_roc_auc: 0.9325 - learning_rate: 0.0010
# Epoch 40/60
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 5s 53ms/step - binary_accuracy: 0.9905 - loss: 0.0240 - pr_auc: 0.6738 - precision_5: 0.1625 - recall_5: 0.9973 - roc_auc: 0.9994 - val_binary_accuracy: 0.9952 - val_loss: 0.0221 - val_pr_auc: 0.5792 - val_precision_5: 0.2412 - val_recall_5: 0.8378 - val_roc_auc: 0.9404 - learning_rate: 0.0010
# Epoch 41/60
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 4s 41ms/step - binary_accuracy: 0.9898 - loss: 0.0308 - pr_auc: 0.6241 - precision_5: 0.1558 - recall_5: 0.9823 - roc_auc: 0.9991 - val_binary_accuracy: 0.9952 - val_loss: 0.0225 - val_pr_auc: 0.5893 - val_precision_5: 0.2430 - val_recall_5: 0.8243 - val_roc_auc: 0.9331 - learning_rate: 0.0010
# Epoch 42/60
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 6s 50ms/step - binary_accuracy: 0.9929 - loss: 0.0211 - pr_auc: 0.6828 - precision_5: 0.2051 - recall_5: 0.9947 - roc_auc: 0.9994 - val_binary_accuracy: 0.9954 - val_loss: 0.0226 - val_pr_auc: 0.5709 - val_precision_5: 0.2530 - val_recall_5: 0.8514 - val_roc_auc: 0.9409 - learning_rate: 0.0010
# Epoch 43/60
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 4s 43ms/step - binary_accuracy: 0.9924 - loss: 0.0240 - pr_auc: 0.6230 - precision_5: 0.1856 - recall_5: 0.9954 - roc_auc: 0.9993 - val_binary_accuracy: 0.9932 - val_loss: 0.0278 - val_pr_auc: 0.5347 - val_precision_5: 0.1818 - val_recall_5: 0.8378 - val_roc_auc: 0.9395 - learning_rate: 0.0010
# Epoch 44/60
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 4s 42ms/step - binary_accuracy: 0.9908 - loss: 0.0296 - pr_auc: 0.6172 - precision_5: 0.1507 - recall_5: 0.9827 - roc_auc: 0.9992 - val_binary_accuracy: 0.9965 - val_loss: 0.0187 - val_pr_auc: 0.5795 - val_precision_5: 0.3096 - val_recall_5: 0.8243 - val_roc_auc: 0.9339 - learning_rate: 0.0010
# Epoch 45/60
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 5s 53ms/step - binary_accuracy: 0.9916 - loss: 0.0250 - pr_auc: 0.7064 - precision_5: 0.1860 - recall_5: 0.9901 - roc_auc: 0.9994 - val_binary_accuracy: 0.9929 - val_loss: 0.0269 - val_pr_auc: 0.5913 - val_precision_5: 0.1746 - val_recall_5: 0.8378 - val_roc_auc: 0.9318 - learning_rate: 0.0010
# Epoch 46/60
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 4s 40ms/step - binary_accuracy: 0.9892 - loss: 0.0328 - pr_auc: 0.5941 - precision_5: 0.1463 - recall_5: 0.9858 - roc_auc: 0.9990 - val_binary_accuracy: 0.9914 - val_loss: 0.0318 - val_pr_auc: 0.4485 - val_precision_5: 0.1487 - val_recall_5: 0.8378 - val_roc_auc: 0.9372 - learning_rate: 0.0010
# Epoch 47/60
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 4s 41ms/step - binary_accuracy: 0.9892 - loss: 0.0354 - pr_auc: 0.5519 - precision_5: 0.1411 - recall_5: 0.9833 - roc_auc: 0.9989 - val_binary_accuracy: 0.9922 - val_loss: 0.0279 - val_pr_auc: 0.5510 - val_precision_5: 0.1636 - val_recall_5: 0.8514 - val_roc_auc: 0.9391 - learning_rate: 0.0010
# Epoch 48/60
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 5s 54ms/step - binary_accuracy: 0.9911 - loss: 0.0269 - pr_auc: 0.6092 - precision_5: 0.1610 - recall_5: 0.9947 - roc_auc: 0.9992 - val_binary_accuracy: 0.9930 - val_loss: 0.0332 - val_pr_auc: 0.5586 - val_precision_5: 0.1785 - val_recall_5: 0.8514 - val_roc_auc: 0.9321 - learning_rate: 0.0010
# Epoch 49/60
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 4s 42ms/step - binary_accuracy: 0.9872 - loss: 0.0349 - pr_auc: 0.5262 - precision_5: 0.1156 - recall_5: 0.9968 - roc_auc: 0.9988 - val_binary_accuracy: 0.9877 - val_loss: 0.0514 - val_pr_auc: 0.3540 - val_precision_5: 0.1078 - val_recall_5: 0.8378 - val_roc_auc: 0.9439 - learning_rate: 0.0010
# Epoch 50/60
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 4s 41ms/step - binary_accuracy: 0.9845 - loss: 0.0326 - pr_auc: 0.4329 - precision_5: 0.1023 - recall_5: 0.9997 - roc_auc: 0.9987 - val_binary_accuracy: 0.9909 - val_loss: 0.0385 - val_pr_auc: 0.4441 - val_precision_5: 0.1412 - val_recall_5: 0.8378 - val_roc_auc: 0.9445 - learning_rate: 1.0000e-04
# Epoch 51/60
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 5s 55ms/step - binary_accuracy: 0.9879 - loss: 0.0232 - pr_auc: 0.5650 - precision_5: 0.1214 - recall_5: 1.0000 - roc_auc: 0.9992 - val_binary_accuracy: 0.9934 - val_loss: 0.0312 - val_pr_auc: 0.5062 - val_precision_5: 0.1873 - val_recall_5: 0.8378 - val_roc_auc: 0.9386 - learning_rate: 1.0000e-04
# Epoch 52/60
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 4s 40ms/step - binary_accuracy: 0.9910 - loss: 0.0233 - pr_auc: 0.6121 - precision_5: 0.1570 - recall_5: 0.9951 - roc_auc: 0.9993 - val_binary_accuracy: 0.9940 - val_loss: 0.0286 - val_pr_auc: 0.5180 - val_precision_5: 0.2026 - val_recall_5: 0.8378 - val_roc_auc: 0.9394 - learning_rate: 1.0000e-04
# Epoch 53/60
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 5s 43ms/step - binary_accuracy: 0.9912 - loss: 0.0217 - pr_auc: 0.6130 - precision_5: 0.1528 - recall_5: 0.9980 - roc_auc: 0.9994 - val_binary_accuracy: 0.9942 - val_loss: 0.0268 - val_pr_auc: 0.5291 - val_precision_5: 0.2095 - val_recall_5: 0.8378 - val_roc_auc: 0.9396 - learning_rate: 1.0000e-04
# Epoch 54/60
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 5s 50ms/step - binary_accuracy: 0.9921 - loss: 0.0185 - pr_auc: 0.7105 - precision_5: 0.1859 - recall_5: 0.9933 - roc_auc: 0.9995 - val_binary_accuracy: 0.9945 - val_loss: 0.0257 - val_pr_auc: 0.5466 - val_precision_5: 0.2183 - val_recall_5: 0.8378 - val_roc_auc: 0.9398 - learning_rate: 1.0000e-04
# Epoch 55/60
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 4s 40ms/step - binary_accuracy: 0.9923 - loss: 0.0185 - pr_auc: 0.6572 - precision_5: 0.1690 - recall_5: 0.9999 - roc_auc: 0.9995 - val_binary_accuracy: 0.9951 - val_loss: 0.0240 - val_pr_auc: 0.5766 - val_precision_5: 0.2385 - val_recall_5: 0.8378 - val_roc_auc: 0.9400 - learning_rate: 1.0000e-04
# Epoch 55: early stopping
# Restoring model weights from the end of the best epoch: 37.

# %%
loss, pr_auc, roc_auc, accuracy, precision, recall = model.evaluate(test_x_np, test_y_np)
# Out:
# 1336/1336 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - binary_accuracy: 0.9936 - loss: 0.0241 - pr_auc: 0.6672 - precision_5: 0.2052 - recall_5: 0.9188 - roc_auc: 0.9674

# %%
print(loss, pr_auc, roc_auc, accuracy, precision, recall)
# Out:
# 0.022992033511400223 0.6704648733139038 0.9745488166809082 0.9936800599098206 0.20121951401233673 0.8918918967247009
